# %% [markdown]
# # Using the Natural Language Toolkit

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Go ahead and create a new Python file. You can add this code to get the PoS tags for the text you provide:

# %%
import nltk
from nltk import word_tokenize
text = word_tokenize("I enjoy biking on the trails")
output = nltk.pos_tag(text)
print(output)

# %% [markdown]
# When you run this file, it will print out the PoS tags for each word

# %% [markdown]
# ![image.png](attachment:image.png)
